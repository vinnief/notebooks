# %% [markdown]
# # Just a test of Jupyter with python, running a script in the notebooks.

# %%
import numpy as np
from math import sin, cos, pi
import matplotlib.pyplot as plt

# %%
def f(x):  
     return np.exp(-x ** 2)
def g(x): 
    return np.sin (x **2) +1
# %load_ext autoreload
# %autoreload 1
(type( g) , type (f))
# Out:
# (function, function)

# %%
x = np.linspace(-4, 3, 100)

# %%
[(a,f(a)) for a in x[range(3)]]
# Out:
# [(-4.0, 1.1253517471925912e-07),
#  (-3.9292929292929295, 1.9714173021029335e-07),
#  (-3.8585858585858586, 3.419214419811645e-07)]

# %%
list(map(g,x[0:3]))
# Out:
# [0.7120966833349347, 1.2654015107220848, 1.7306533758115563]

# %%
import myplot
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\feltkamp\.julia\conda\3\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-14-326076b5ec69>", line 1, in <module>
#     import myplot
#
#   File "D:\gits\notebooks\myplot.py", line 19
#     def plotpolar(f,t, mint = -3*pi, maxt=6*pi)
#                                                ^
# SyntaxError: invalid syntax

# %%
myplot.plotfn(f, x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1db1cc490f55> in <module>
# ----> 1 myplot.plotfn(f, x)
#
# NameError: name 'myplot' is not defined

# %%
# ?plot_f_x.myplot

# %%
plot_f_x.myplot(g, x)

# %%
x = np.linspace(.1, 3, 100)
plot_f_x.myplot(lambda y: sin(y)/ y, x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-5ead9565f323> in <module>
#       1 x = np.linspace(.1, 3, 100)
# ----> 2 plot_f_x.myplot(lambda y: sin(y)/ y, x)
#
# D:\gits\notebooks\plot_f_x.py in myplot(f, x)
#      12     # yes, you can pass functions around as if
#      13     # they were ordinary variables (they are)
# ---> 14     plt.plot(x, f(x))
#      15     plt.xlabel("Eje $x$",fontsize=16)
#      16     plt.ylabel("$f(x)$",fontsize=16)
#
# <ipython-input-128-5ead9565f323> in <lambda>(y)
#       1 x = np.linspace(.1, 3, 100)
# ----> 2 plot_f_x.myplot(lambda y: sin(y)/ y, x)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
[(a,(lambda y: sin(y)/y)(a)) for a in x[range(3)]]
# Out:
# [(0.1, 0.9983341664682815),
#  (0.1292929292929293, 0.9972162175356046),
#  (0.15858585858585858, 0.9958136885549753)]

# %%
t = np.linspace(0,8.1*pi,501)
p= 1.7
def h(t): return sin(p*t)
x = list(map( lambda t: sin(t*2*pi)*h(t), t))
y = list(map( lambda t: cos(t*2*pi)*h(t), t))
plt.plot(x,y)

# %%
t = np.linspace(0,5*pi,501)
p= .1
def h(t): return sin(p*t*2*pi)
x = list(map( lambda t: sin(t*2*pi)*h(t), t))
y = list(map( lambda t: cos(t*2*pi)*h(t), t))
plt.plot(x,y)

# %%
t = np.linspace(0,5*pi,501)
p= .1
def h(t): return sin(p*t*2*pi)
x = list(map( lambda t: sin(t*2*pi)*h(t), t))
y = list(map( lambda t: cos(t*2*pi)*h(t), t))
plt.plot(x,y)
